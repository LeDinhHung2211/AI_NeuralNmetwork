# %% [markdown]
# <a href="https://www.kaggle.com/code/hunhun2211/fruit?scriptVersionId=96099522" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/fruitdata/fruit',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/fruitdata/fruit',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 80 images belonging to 10 classes.
# Found 19 images belonging to 10 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'apple': 0,
#  'banana': 1,
#  'carrot': 2,
#  'grapes': 3,
#  'lemon': 4,
#  'mango': 5,
#  'orange': 6,
#  'pineapple': 7,
#  'potato': 8,
#  'tomato': 9}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-20 07:49:57.012019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:57.126120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:57.126939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:57.128084: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-20 07:49:57.128374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:57.129100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:57.129897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:59.267462: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:59.268694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:59.269679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:49:59.271269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=32,epochs=50,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-20 07:50:01.079728: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-05-20 07:50:03.529861: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 8/8 [==============================] - 14s 783ms/step - loss: 2.5855 - accuracy: 0.1250 - val_loss: 2.3811 - val_accuracy: 0.1053
# Epoch 2/50
# 8/8 [==============================] - 5s 726ms/step - loss: 2.2546 - accuracy: 0.1250 - val_loss: 2.2128 - val_accuracy: 0.1053
# Epoch 3/50
# 8/8 [==============================] - 5s 554ms/step - loss: 2.1214 - accuracy: 0.3125 - val_loss: 2.1375 - val_accuracy: 0.1579
# Epoch 4/50
# 8/8 [==============================] - 5s 639ms/step - loss: 1.8898 - accuracy: 0.3750 - val_loss: 2.0716 - val_accuracy: 0.2105
# Epoch 5/50
# 8/8 [==============================] - 6s 722ms/step - loss: 1.6800 - accuracy: 0.5000 - val_loss: 1.8672 - val_accuracy: 0.3684
# Epoch 6/50
# 8/8 [==============================] - 5s 655ms/step - loss: 1.5386 - accuracy: 0.4750 - val_loss: 1.7737 - val_accuracy: 0.3684
# Epoch 7/50
# 8/8 [==============================] - 5s 687ms/step - loss: 1.3088 - accuracy: 0.5250 - val_loss: 1.6492 - val_accuracy: 0.3158
# Epoch 8/50
# 8/8 [==============================] - 5s 681ms/step - loss: 0.9493 - accuracy: 0.7125 - val_loss: 1.4885 - val_accuracy: 0.4737
# Epoch 9/50
# 8/8 [==============================] - 5s 628ms/step - loss: 0.8846 - accuracy: 0.7625 - val_loss: 1.3290 - val_accuracy: 0.5263
# Epoch 10/50
# 8/8 [==============================] - 6s 745ms/step - loss: 0.5784 - accuracy: 0.8250 - val_loss: 1.5997 - val_accuracy: 0.5263
# Epoch 11/50
# 8/8 [==============================] - 6s 824ms/step - loss: 0.4543 - accuracy: 0.8625 - val_loss: 1.2728 - val_accuracy: 0.4737
# Epoch 12/50
# 8/8 [==============================] - 5s 564ms/step - loss: 0.2912 - accuracy: 0.9250 - val_loss: 1.4032 - val_accuracy: 0.6842
# Epoch 13/50
# 8/8 [==============================] - 6s 756ms/step - loss: 0.2435 - accuracy: 0.9000 - val_loss: 1.2655 - val_accuracy: 0.4737
# Epoch 14/50
# 8/8 [==============================] - 5s 579ms/step - loss: 0.3861 - accuracy: 0.9000 - val_loss: 1.6625 - val_accuracy: 0.5789
# Epoch 15/50
# 8/8 [==============================] - 6s 770ms/step - loss: 0.3510 - accuracy: 0.9000 - val_loss: 1.9930 - val_accuracy: 0.4737
# Epoch 16/50
# 8/8 [==============================] - 6s 761ms/step - loss: 0.2522 - accuracy: 0.9125 - val_loss: 1.3719 - val_accuracy: 0.6316
# Epoch 17/50
# 8/8 [==============================] - 5s 640ms/step - loss: 0.1315 - accuracy: 0.9875 - val_loss: 1.2011 - val_accuracy: 0.6316
# Epoch 18/50
# 8/8 [==============================] - 5s 673ms/step - loss: 0.1374 - accuracy: 0.9375 - val_loss: 1.2828 - val_accuracy: 0.6842
# Epoch 19/50
# 8/8 [==============================] - 6s 711ms/step - loss: 0.0904 - accuracy: 0.9750 - val_loss: 1.6737 - val_accuracy: 0.6842
# Epoch 20/50
# 8/8 [==============================] - 5s 673ms/step - loss: 0.0554 - accuracy: 0.9875 - val_loss: 1.4829 - val_accuracy: 0.7368
# Epoch 21/50
# 8/8 [==============================] - 5s 732ms/step - loss: 0.0702 - accuracy: 0.9875 - val_loss: 1.3740 - val_accuracy: 0.5789
# Epoch 22/50
# 8/8 [==============================] - 6s 785ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 1.5539 - val_accuracy: 0.6316
# Epoch 23/50
# 8/8 [==============================] - 5s 688ms/step - loss: 0.0563 - accuracy: 0.9875 - val_loss: 1.8087 - val_accuracy: 0.5263
# Epoch 24/50
# 8/8 [==============================] - 5s 652ms/step - loss: 0.0733 - accuracy: 0.9750 - val_loss: 1.6759 - val_accuracy: 0.6316
# Epoch 25/50
# 8/8 [==============================] - 5s 665ms/step - loss: 0.1121 - accuracy: 0.9500 - val_loss: 1.8635 - val_accuracy: 0.6842
# Epoch 26/50
# 8/8 [==============================] - 5s 698ms/step - loss: 0.0852 - accuracy: 0.9875 - val_loss: 1.4290 - val_accuracy: 0.5789
# Epoch 27/50
# 8/8 [==============================] - 6s 769ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 1.4013 - val_accuracy: 0.6842
# Epoch 28/50
# 8/8 [==============================] - 6s 757ms/step - loss: 0.0825 - accuracy: 0.9625 - val_loss: 1.5882 - val_accuracy: 0.5789
# Epoch 29/50
# 8/8 [==============================] - 6s 734ms/step - loss: 0.1073 - accuracy: 0.9500 - val_loss: 1.6334 - val_accuracy: 0.6316
# Epoch 30/50
# 8/8 [==============================] - 5s 708ms/step - loss: 0.1061 - accuracy: 0.9625 - val_loss: 1.8268 - val_accuracy: 0.6842
# Epoch 31/50
# 8/8 [==============================] - 6s 612ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 1.5158 - val_accuracy: 0.5263
# Epoch 32/50
# 8/8 [==============================] - 5s 581ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 1.4160 - val_accuracy: 0.6842
# Epoch 33/50
# 8/8 [==============================] - 5s 674ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.5220 - val_accuracy: 0.5789
# Epoch 34/50
# 8/8 [==============================] - 6s 745ms/step - loss: 0.0559 - accuracy: 0.9750 - val_loss: 1.7757 - val_accuracy: 0.6316
# Epoch 35/50
# 8/8 [==============================] - 6s 685ms/step - loss: 0.0436 - accuracy: 0.9875 - val_loss: 1.5715 - val_accuracy: 0.4737
# Epoch 36/50
# 8/8 [==============================] - 5s 694ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 1.4234 - val_accuracy: 0.5789
# Epoch 37/50
# 8/8 [==============================] - 6s 699ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 1.0668 - val_accuracy: 0.6842
# Epoch 38/50
# 8/8 [==============================] - 5s 714ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.3776 - val_accuracy: 0.6842
# Epoch 39/50
# 8/8 [==============================] - 5s 623ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.5343 - val_accuracy: 0.6842
# Epoch 40/50
# 8/8 [==============================] - 6s 745ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.4409 - val_accuracy: 0.6842
# Epoch 41/50
# 8/8 [==============================] - 6s 617ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.4477 - val_accuracy: 0.6842
# Epoch 42/50
# 8/8 [==============================] - 5s 582ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.4693 - val_accuracy: 0.6842
# Epoch 43/50
# 8/8 [==============================] - 6s 672ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7500 - val_accuracy: 0.6316
# Epoch 44/50
# 8/8 [==============================] - 5s 702ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.7905 - val_accuracy: 0.6316
# Epoch 45/50
# 8/8 [==============================] - 6s 723ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.7484 - val_accuracy: 0.6316
# Epoch 46/50
# 8/8 [==============================] - 6s 781ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.7813 - val_accuracy: 0.6316
# Epoch 47/50
# 8/8 [==============================] - 5s 711ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.6739 - val_accuracy: 0.6316
# Epoch 48/50
# 8/8 [==============================] - 5s 742ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.5232 - val_accuracy: 0.6316
# Epoch 49/50
# 8/8 [==============================] - 6s 626ms/step - loss: 0.0337 - accuracy: 0.9750 - val_loss: 1.7667 - val_accuracy: 0.6316
# Epoch 50/50
# 8/8 [==============================] - 5s 729ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.1621 - val_accuracy: 0.5263

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  2.1621410846710205
# Độ chính xác  0.5263158082962036

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/grape-test/grape_test.jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("apple")
if(kq==1):
    print("banana")
if(kq==2):
    print("carrot")
if(kq==3):
    print("grapes")
if(kq==4):
    print("lemon")
if(kq==5):
    print("mango")
if(kq==6):
    print("orange")
if(kq==7):
    print("pineapple")
if(kq==8):
    print("potato")
if(kq==9):
    print("tomato")
# Out:
# grapes
