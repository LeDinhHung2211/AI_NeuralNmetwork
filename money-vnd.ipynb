# %% [markdown]
# <a href="https://www.kaggle.com/code/hunhun2211/money-vnd?scriptVersionId=96099200" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/money-datasets',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/money-datasets',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 176 images belonging to 11 classes.
# Found 44 images belonging to 11 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-20 07:45:37.073320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:37.193609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:37.194597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:37.195805: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-20 07:45:37.196099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:37.196942: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:37.197681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:39.504218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:39.505170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:39.505930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:45:39.507511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 5,596,971
# Trainable params: 5,596,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])
history=model.fit(train_dataset,batch_size=32,epochs=70,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-20 07:45:40.178129: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/70
# 2022-05-20 07:45:41.889542: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 18/18 [==============================] - 11s 189ms/step - loss: 2.5629 - accuracy: 0.0568 - val_loss: 2.3884 - val_accuracy: 0.1364
# Epoch 2/70
# 18/18 [==============================] - 2s 132ms/step - loss: 2.3827 - accuracy: 0.1250 - val_loss: 2.3582 - val_accuracy: 0.1591
# Epoch 3/70
# 18/18 [==============================] - 2s 116ms/step - loss: 2.3237 - accuracy: 0.1534 - val_loss: 2.2784 - val_accuracy: 0.1136
# Epoch 4/70
# 18/18 [==============================] - 2s 122ms/step - loss: 2.2392 - accuracy: 0.2386 - val_loss: 2.1781 - val_accuracy: 0.2500
# Epoch 5/70
# 18/18 [==============================] - 2s 121ms/step - loss: 2.0584 - accuracy: 0.2955 - val_loss: 2.0253 - val_accuracy: 0.2045
# Epoch 6/70
# 18/18 [==============================] - 2s 118ms/step - loss: 1.8024 - accuracy: 0.3636 - val_loss: 1.6473 - val_accuracy: 0.4318
# Epoch 7/70
# 18/18 [==============================] - 2s 130ms/step - loss: 1.4221 - accuracy: 0.5000 - val_loss: 1.8372 - val_accuracy: 0.2955
# Epoch 8/70
# 18/18 [==============================] - 3s 142ms/step - loss: 1.3236 - accuracy: 0.5625 - val_loss: 1.1680 - val_accuracy: 0.5682
# Epoch 9/70
# 18/18 [==============================] - 2s 117ms/step - loss: 1.0701 - accuracy: 0.6477 - val_loss: 1.1856 - val_accuracy: 0.5909
# Epoch 10/70
# 18/18 [==============================] - 2s 116ms/step - loss: 1.0332 - accuracy: 0.6477 - val_loss: 1.4273 - val_accuracy: 0.4773
# Epoch 11/70
# 18/18 [==============================] - 2s 118ms/step - loss: 0.8682 - accuracy: 0.6932 - val_loss: 1.0293 - val_accuracy: 0.6136
# Epoch 12/70
# 18/18 [==============================] - 2s 133ms/step - loss: 0.7189 - accuracy: 0.8295 - val_loss: 1.1734 - val_accuracy: 0.5455
# Epoch 13/70
# 18/18 [==============================] - 2s 115ms/step - loss: 0.5374 - accuracy: 0.8239 - val_loss: 1.2495 - val_accuracy: 0.5455
# Epoch 14/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.5606 - accuracy: 0.8295 - val_loss: 1.1597 - val_accuracy: 0.6818
# Epoch 15/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.4060 - accuracy: 0.8580 - val_loss: 1.0791 - val_accuracy: 0.6364
# Epoch 16/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.3620 - accuracy: 0.8864 - val_loss: 1.1248 - val_accuracy: 0.7045
# Epoch 17/70
# 18/18 [==============================] - 2s 133ms/step - loss: 0.2949 - accuracy: 0.8864 - val_loss: 1.6243 - val_accuracy: 0.5455
# Epoch 18/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.3038 - accuracy: 0.9318 - val_loss: 0.9412 - val_accuracy: 0.6818
# Epoch 19/70
# 18/18 [==============================] - 2s 118ms/step - loss: 0.1435 - accuracy: 0.9489 - val_loss: 0.9743 - val_accuracy: 0.6818
# Epoch 20/70
# 18/18 [==============================] - 2s 114ms/step - loss: 0.0888 - accuracy: 0.9773 - val_loss: 1.2218 - val_accuracy: 0.7045
# Epoch 21/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.1466 - accuracy: 0.9432 - val_loss: 1.4605 - val_accuracy: 0.6591
# Epoch 22/70
# 18/18 [==============================] - 2s 133ms/step - loss: 0.1457 - accuracy: 0.9489 - val_loss: 1.0698 - val_accuracy: 0.7273
# Epoch 23/70
# 18/18 [==============================] - 3s 155ms/step - loss: 0.0833 - accuracy: 0.9659 - val_loss: 1.2562 - val_accuracy: 0.6364
# Epoch 24/70
# 18/18 [==============================] - 2s 115ms/step - loss: 0.1316 - accuracy: 0.9716 - val_loss: 1.2485 - val_accuracy: 0.6364
# Epoch 25/70
# 18/18 [==============================] - 2s 114ms/step - loss: 0.1300 - accuracy: 0.9659 - val_loss: 0.9686 - val_accuracy: 0.7727
# Epoch 26/70
# 18/18 [==============================] - 3s 140ms/step - loss: 0.0746 - accuracy: 0.9773 - val_loss: 1.0533 - val_accuracy: 0.6818
# Epoch 27/70
# 18/18 [==============================] - 2s 126ms/step - loss: 0.0463 - accuracy: 0.9943 - val_loss: 1.2298 - val_accuracy: 0.6818
# Epoch 28/70
# 18/18 [==============================] - 2s 115ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.2698 - val_accuracy: 0.7273
# Epoch 29/70
# 18/18 [==============================] - 2s 114ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.3332 - val_accuracy: 0.7273
# Epoch 30/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.2791 - val_accuracy: 0.7045
# Epoch 31/70
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.4151 - val_accuracy: 0.6591
# Epoch 32/70
# 18/18 [==============================] - 2s 120ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.3107 - val_accuracy: 0.7273
# Epoch 33/70
# 18/18 [==============================] - 2s 114ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.5217 - val_accuracy: 0.7045
# Epoch 34/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0569 - accuracy: 0.9830 - val_loss: 1.2962 - val_accuracy: 0.6818
# Epoch 35/70
# 18/18 [==============================] - 2s 122ms/step - loss: 0.1767 - accuracy: 0.9375 - val_loss: 1.1701 - val_accuracy: 0.6591
# Epoch 36/70
# 18/18 [==============================] - 3s 157ms/step - loss: 0.1104 - accuracy: 0.9773 - val_loss: 0.9805 - val_accuracy: 0.7273
# Epoch 37/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.0347 - accuracy: 0.9830 - val_loss: 1.1301 - val_accuracy: 0.6591
# Epoch 38/70
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0392 - accuracy: 0.9830 - val_loss: 1.2836 - val_accuracy: 0.6591
# Epoch 39/70
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0371 - accuracy: 0.9886 - val_loss: 1.3580 - val_accuracy: 0.7045
# Epoch 40/70
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.7500
# Epoch 41/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 1.2640 - val_accuracy: 0.7273
# Epoch 42/70
# 18/18 [==============================] - 2s 110ms/step - loss: 0.0122 - accuracy: 0.9943 - val_loss: 1.3820 - val_accuracy: 0.7273
# Epoch 43/70
# 18/18 [==============================] - 2s 115ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.5043 - val_accuracy: 0.7273
# Epoch 44/70
# 18/18 [==============================] - 2s 124ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.3718 - val_accuracy: 0.7045
# Epoch 45/70
# 18/18 [==============================] - 2s 112ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.2347 - val_accuracy: 0.7500
# Epoch 46/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0122 - accuracy: 0.9943 - val_loss: 1.1857 - val_accuracy: 0.7045
# Epoch 47/70
# 18/18 [==============================] - 2s 113ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.1456 - val_accuracy: 0.7273
# Epoch 48/70
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.2539 - val_accuracy: 0.7500
# Epoch 49/70
# 18/18 [==============================] - 3s 147ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 1.4298 - val_accuracy: 0.7273
# Epoch 50/70
# 18/18 [==============================] - 2s 118ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.5019 - val_accuracy: 0.7273
# Epoch 51/70
# 18/18 [==============================] - 3s 137ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.4702 - val_accuracy: 0.7273
# Epoch 52/70
# 18/18 [==============================] - 2s 118ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.4584 - val_accuracy: 0.7273
# Epoch 53/70
# 18/18 [==============================] - 2s 113ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4419 - val_accuracy: 0.7500
# Epoch 54/70
# 18/18 [==============================] - 2s 129ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.3587 - val_accuracy: 0.7273
# Epoch 55/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3506 - val_accuracy: 0.7045
# Epoch 56/70
# 18/18 [==============================] - 2s 121ms/step - loss: 0.0135 - accuracy: 0.9943 - val_loss: 1.3215 - val_accuracy: 0.7273
# Epoch 57/70
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.7809 - val_accuracy: 0.6591
# Epoch 58/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.7955
# Epoch 59/70
# 18/18 [==============================] - 2s 134ms/step - loss: 9.0915e-04 - accuracy: 1.0000 - val_loss: 1.1997 - val_accuracy: 0.7955
# Epoch 60/70
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.2718 - val_accuracy: 0.7955
# Epoch 61/70
# 18/18 [==============================] - 2s 115ms/step - loss: 0.0125 - accuracy: 0.9943 - val_loss: 1.5103 - val_accuracy: 0.7273
# Epoch 62/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.4917 - val_accuracy: 0.7727
# Epoch 63/70
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.4918 - val_accuracy: 0.7500
# Epoch 64/70
# 18/18 [==============================] - 2s 138ms/step - loss: 4.2640e-04 - accuracy: 1.0000 - val_loss: 1.4813 - val_accuracy: 0.7500
# Epoch 65/70
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0105 - accuracy: 0.9943 - val_loss: 1.5044 - val_accuracy: 0.7273
# Epoch 66/70
# 18/18 [==============================] - 3s 150ms/step - loss: 0.0109 - accuracy: 0.9943 - val_loss: 1.5957 - val_accuracy: 0.7500
# Epoch 67/70
# 18/18 [==============================] - 2s 116ms/step - loss: 0.0089 - accuracy: 0.9943 - val_loss: 1.5621 - val_accuracy: 0.7500
# Epoch 68/70
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.4309 - val_accuracy: 0.7727
# Epoch 69/70
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0098 - accuracy: 0.9943 - val_loss: 1.3997 - val_accuracy: 0.7955
# Epoch 70/70
# 18/18 [==============================] - 2s 122ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.4070 - val_accuracy: 0.6818

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.4069758653640747
# Độ chính xác  0.6818181872367859

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/money-datasets/2000/16.jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq=np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("1k")
if(kq==1):
    print("10k")
if(kq==2):
    print("100k")
if(kq==3):
    print("200")
if(kq==4):
    print("2k")
if(kq==5):
    print("20k")
if(kq==6):
    print("200k")
if(kq==7):
    print("500")
if(kq==8):
    print("5k")
if(kq==9):
    print("50k")
if(kq==10):
    print("500k")
# Out:
# 2k
